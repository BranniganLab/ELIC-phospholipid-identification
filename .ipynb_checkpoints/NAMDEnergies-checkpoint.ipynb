# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
PG = pd.read_csv("ARG318_POEG", delim_whitespace=True)

# %%
plt.plot(PG.Time, PG.Total)
plt.xlabel("Time in ps")
plt.ylabel("Nonbonded Energy (kcal/mol)")
# Out:
# Text(0, 0.5, 'Nonbonded Energy (kcal/mol)')

# %%
plt.hist(PG.Total)
# Out:
# (array([ 10., 147., 381., 762., 755., 380., 247., 110.,  84.,  21.]),
#  array([-85.656  , -78.58011, -71.50422, -64.42833, -57.35244, -50.27655,
#         -43.20066, -36.12477, -29.04888, -21.97299, -14.8971 ]),
#  <BarContainer object of 10 artists>)

# %%
PE = pd.read_csv("ARG318_PE", delim_whitespace=True)

# %%
plt.plot(PE.Time, PE.Total)
plt.xlabel("Time in ps")
plt.ylabel("Nonbonded Energy (kcal/mol)")
# Out:
# Text(0, 0.5, 'Nonbonded Energy (kcal/mol)')

# %%
plt.hist(PE.Total)
# Out:
# (array([  9., 178., 735., 821., 424., 292., 244., 160.,  40.,   8.]),
#  array([-57.8147 , -54.13855, -50.4624 , -46.78625, -43.1101 , -39.43395,
#         -35.7578 , -32.08165, -28.4055 , -24.72935, -21.0532 ]),
#  <BarContainer object of 10 artists>)
