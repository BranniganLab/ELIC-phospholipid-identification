# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("bobs_unaligned.dat", delim_whitespace=True, names=["frame", ('ligand', 'X'),('ligand', 'Y'),('ligand', 'Z'),('BobB', 'X'),('BobB', 'Y'),('BobB', 'Z'),('BobC', 'X'),('BobC', 'Y'),('BobC', 'Z'),('BobD', 'X'),('BobD', 'Y'),('BobD', 'Z'),('BobE', 'X'),('BobE', 'Y'),('BobE', 'Z')])
data = data.set_index("frame")

# %%
data.columns = pd.MultiIndex.from_tuples(data.columns)

# %%
data
# Out:
#          ligand                          BobB                          BobC  \
#               X         Y         Z         X         Y         Z         X
# frame
# 0      6.324566 -0.488865 -1.492000  4.884050 -4.266519  2.674396 -6.968366
# 1      5.536108 -0.330037 -3.941438  6.297568 -2.758889  1.047320 -7.643305
# 2      5.932954 -0.159423 -3.457223  6.224771 -2.842758  1.218558 -7.966286
# 3      6.076279 -0.597257 -3.047765  6.082657 -3.433213  1.215837 -8.366657
# 4      5.648093 -0.248271 -3.807574  6.250385 -3.133532  1.429246 -7.752616
# ...         ...       ...       ...       ...       ...       ...       ...
# 996    5.922567  0.685317 -1.425229  6.535729 -2.994867  2.411759 -8.633287
# 997    5.719123  0.791532 -1.386145  6.789985 -3.058897  2.411397 -8.638173
# 998    6.233040  0.474086 -1.246298  6.697528 -3.095750  2.508168 -8.617870
# 999    5.854961  0.231027 -2.066531  6.719086 -3.024116  2.365862 -8.735204
# 1000   5.685288  0.357980 -1.552736  6.323489 -3.290319  2.639154 -8.447340
#
#                                BobD                          BobE            \
#               Y         Z         X         Y         Z         X         Y
# frame
# 0      0.728610  2.453927 -0.808555  7.841801  1.086267 -6.160542 -6.103529
# 1     -1.393815  1.912458 -1.569766  6.755760  2.609341 -5.026007 -6.047999
# 2     -1.302049  1.866965 -1.049374  6.722087  2.063928 -5.213804 -5.921724
# 3     -1.761230  1.952982 -1.074695  6.712790  2.396416 -5.229671 -5.994931
# 4     -0.777286  2.090005 -1.588639  6.821894  2.016826 -4.898417 -6.178577
# ...         ...       ...       ...       ...       ...       ...       ...
# 996   -0.048416  1.662386 -2.507132  7.768914  1.822569 -5.561759 -4.872534
# 997    0.167268  1.648622 -2.270643  7.870783  2.228417 -5.480759 -4.962596
# 998   -0.122148  1.600229 -2.666269  8.098731  1.967384 -5.422770 -5.284210
# 999   -0.055553  1.130628 -2.559559  8.298836  2.112253 -5.501970 -4.988286
# 1000   0.065006  1.236674 -2.821808  7.990507  1.728087 -5.467875 -4.866365
#
#
#               Z
# frame
# 0      1.598747
# 1      0.963384
# 2      0.952431
# 3      0.670101
# 4      0.700298
# ...         ...
# 996    0.844037
# 997    1.039599
# 998    0.971336
# 999    1.126684
# 1000   1.260830
#
# [1001 rows x 15 columns]

# %%
#fig, ax = plt.subplots()
plotData = data.ligand
X = plotData.X
Y = plotData.Y
plt.scatter(X, Y)
plt.scatter(0, 0, color="orange")
plt.title(f"Entire Lipid COM Position (XY)")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
upperX = np.max([0, np.max(X)])
lowerX = np.min([np.min(X), 0])
upperY = np.max([0, np.max(Y)])
lowerY = np.min([np.min(Y), 0])
print(f"[[{lowerX},{upperX}],[{lowerY},{upperY}]]")
plt.xlim([lowerX-1, upperX+1])
plt.ylim([lowerY+1, upperY-1])

plt.show()
#plt.savefig("XYPosition.png", dpi=600)
# Out:
# [[0.0,6.95240065010754],[-1.50949677212875,1.18434552613362]]

# %%
#fig, ax = plt.subplots()
plotData = data.BobB
X = plotData.X
Y = plotData.Y
plt.scatter(X, Y)
plt.scatter(0, 0, color="orange")
plt.title(f"Entire Lipid COM Position (XY)")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
upperX = np.max([0, np.max(X)])
lowerX = np.min([np.min(X), 0])
upperY = np.max([0, np.max(Y)])
lowerY = np.min([np.min(Y), 0])
print(f"[[{lowerX},{upperX}],[{lowerY},{upperY}]]")
plt.xlim([lowerX-1, upperX+1])
plt.ylim([lowerY+1, upperY-1])

plt.show()
# Out:
# [[0.0,7.81695043534587],[-4.73507302853296,0.0]]

# %%
#fig, ax = plt.subplots()
plotData = data.BobC
X = plotData.X
Y = plotData.Y
plt.scatter(X, Y)
plt.scatter(0, 0, color="orange")
plt.title(f"Entire Lipid COM Position (XY)")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
upperX = np.max([0, np.max(X)])
lowerX = np.min([np.min(X), 0])
upperY = np.max([0, np.max(Y)])
lowerY = np.min([np.min(Y), 0])
print(f"[[{lowerX},{upperX}],[{lowerY},{upperY}]]")
plt.xlim([lowerX-1, upperX+1])
plt.ylim([lowerY+1, upperY-1])

plt.show()
#plt.savefig("XYPosition.png", dpi=600)
# Out:
# [[-9.53680856050492,0.0],[-2.33705406526601,1.74516964118515]]

# %%
fig, ax = plt.subplots()

plotData = data.BobD
X = plotData.X
Y = plotData.Y
plt.scatter(X, Y)
plt.scatter(0, 0, color="orange")
plt.title(f"Entire Lipid COM Position (XY)")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
upperX = np.max([0, np.max(X)])
lowerX = np.min([np.min(X), 0])
upperY = np.max([0, np.max(Y)])
lowerY = np.min([np.min(Y), 0])
print(f"[[{lowerX},{upperX}],[{lowerY},{upperY}]]")
plt.xlim([lowerX, upperX])
plt.ylim([lowerY-1, upperY+1])

plt.show()
#plt.savefig("XYPosition.png", dpi=600)
# Out:
# [[-3.70768702904824,0.0],[0.0,9.13224603157073]]

# %%
#fig, ax = plt.subplots()
plotData = data.BobE
X = plotData.X
Y = plotData.Y
plt.scatter(X, Y)
plt.scatter(0, 0, color="orange")
plt.title(f"Entire Lipid COM Position (XY)")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
upperX = np.max([0, np.max(X)])
lowerX = np.min([np.min(X), 0])
upperY = np.max([0, np.max(Y)])
lowerY = np.min([np.min(Y), 0])
print(f"[[{lowerX},{upperX}],[{lowerY},{upperY}]]")
plt.xlim([lowerX-3, upperX+3])
plt.ylim([lowerY-3, upperY+3])

plt.show()
#plt.savefig("XYPosition.png", dpi=600)
# Out:
# [[-6.9806721478105,0.0],[-7.16341985286503,0.0]]

# %%
fig, ax = plt.subplots()

plotData = data.ligand
X = plotData.X
Y = plotData.Y
scatterLig = ax.scatter(X, Y, label="ligand")
plotData = data.BobB
X = plotData.X
Y = plotData.Y
scatterB = ax.scatter(X, Y, label="BobB")
plotData = data.BobC
X = plotData.X
Y = plotData.Y
scatterC = ax.scatter(X, Y, label="BobC")
plotData = data.BobD
X = plotData.X
Y = plotData.Y
scatterD = ax.scatter(X, Y, label="BobD")
plotData = data.BobE
X = plotData.X
Y = plotData.Y
scatterE = ax.scatter(X, Y, label="BobE")

plt.legend()

# %%
def getRotationMatrix (vec1, vec2):
    #Convert both vectors to unit vectors, then get the transform between them.
    unit_vec1 = vec1 / np.linalg.norm(vec1)
    unit_vec2 = vec2 / np.linalg.norm(vec2)
    
    if len(vec1) != len(vec2):
        print("Error: vectors of different dimensions.")
        raise
    
    v = np.cross(unit_vec1, unit_vec2)
    s = np.linalg.norm(v) #sin of the angle
    c = np.dot(unit_vec1, unit_vec2) #cos of the angle
    
    try:
        vx = np.cross(v, np.identity(v.shape[0]) * -1) #cross product matrix of v
    except:
        vx = [[0,-v],[v,0]] #for 2D vectors
    
    I = np.identity(len(vec2))
    squared = np.linalg.matrix_power(vx, 2)
    coeff = (1-c)/s**2
    if coeff == np.inf:
        coeff = 0
    
    R = I + vx + squared*coeff
    
    return R

# %%
def rotateData (plotData, target):
    XY = list(zip(plotData.X, plotData.Y))
    center = (np.average(plotData.X), np.average(plotData.Y))
    R = getRotationMatrix(center, target)
    for idx in np.arange(len(XY)):
        XY[idx] = np.dot(R, XY[idx])

    return zip(*XY)

# %%
#Rotate the data so that the COM vectors are parallel. Point-point distances are invariant.
# %matplotlib inline
fig, ax = plt.subplots()

plotData = data.ligand.iloc[200:]
X = plotData.X
Y = plotData.Y
scatterLig = ax.scatter(X, Y, label="ligand")
centerL = (np.average(data.ligand.X.iloc[200:]), np.average(data.ligand.Y.iloc[200:]))

X, Y = rotateData(data.BobB.iloc[200:], centerL)
scatterB = ax.scatter(X, Y, label="BobB")

X,Y = rotateData(data.BobC.iloc[200:], centerL)
scatterC = ax.scatter(X, Y, label="BobC")

X,Y = rotateData(data.BobD.iloc[200:], centerL)
scatterD = ax.scatter(X, Y, label="BobD")

X, Y = rotateData(data.BobE.iloc[200:], centerL)
scatterE = ax.scatter(X, Y, label="BobE")

plt.gca().axis('equal')
plt.legend()

# %%
def getXYDistances(subset):
    XY = list(zip(subset.X, subset.Y))
    dist = []
    for xy in XY:
        dist.append(np.linalg.norm(xy))
        
    return dist

# %%
data["ligand","XYD"] = getXYDistances(data.ligand)
data["BobB", "XYD"] = getXYDistances(data.BobB)
data["BobC", "XYD"] = getXYDistances(data.BobC)
data["BobD", "XYD"] = getXYDistances(data.BobD)
data["BobE", "XYD"] = getXYDistances(data.BobE)
data = data.sort_index(axis=1)

# %%
fig, ax = plt.subplots()
data.ligand.XYD.hist(label="ligand", histtype="step", linewidth=2, bins=30)
data.BobB.XYD.hist(label="BobB", histtype="step", linewidth=2, bins=30)
data.BobC.XYD.hist(label="BobC", histtype="step", linewidth=2, bins=30)
data.BobD.XYD.hist(label="BobD", histtype="step", linewidth=2, bins=30)
data.BobE.XYD.hist(label="BobE", histtype="step", linewidth=2, bins=30)

plt.legend()
plt.title("Entire Lipid COM Distance from Ligand Position at T=0")
plt.ylabel("count")
plt.xlabel("A")
plt.grid(False)
#plt.savefig("Distance_from_t0.png", dpi=600)

# %%
aggregate = np.concatenate([data.ligand.XYD, data.BobB.XYD, data.BobC.XYD, data.BobD.XYD, data.BobE.XYD])
data.ligand.XYD.hist(label="ligand", histtype="step", linewidth=2, bins=30, density=True)
plt.hist(aggregate, label="AllBob", histtype="step", linewidth=2, bins=30, density=True)
plt.legend()

# %%
print(f"95th Percentile: {np.percentile(aggregate, 95)}")
print(f"5th Percentile: {np.percentile(aggregate, 5)}")
# Out:
# 95th Percentile: 8.651988575125129
# 5th Percentile: 5.667924741361684

# %%
import scipy.stats as stats
print(stats.skewtest(aggregate))
print(stats.kurtosistest(aggregate))
# Out:
# SkewtestResult(statistic=2.4835892481439275, pvalue=0.013006573751711244)
# KurtosistestResult(statistic=0.8569151556267356, pvalue=0.3914917762514192)

# %%
# Get Center

# %%
Xs = []
Ys = []

plotData = data.ligand.iloc[200:]
X = plotData.X
Y = plotData.Y
Xs.append(X.values)
Ys.append(Y.values)

X, Y = rotateData(data.BobB.iloc[200:], centerL)
Xs.append(X)
Ys.append(Y)
X,Y = rotateData(data.BobC.iloc[200:], centerL)
Xs.append(X)
Ys.append(Y)
X,Y = rotateData(data.BobD.iloc[200:], centerL)
Xs.append(X)
Ys.append(Y)
X, Y = rotateData(data.BobE.iloc[200:], centerL)
Xs.append(X)
Ys.append(Y)

# %%
print(f"Center: ({np.mean(Xs)}, {np.mean(Ys)})")
# Out:
# Center: (7.191524619245218, -0.3261272567040956)

# %%
fig, ax = plt.subplots()
data.cylLigand.hist(label="ligand")
data.cyl20.hist()
data.cyl25.hist()
data.cyl30.hist()
data.cyl46.hist()
data.cyl6.hist()
plt.legend()
plt.title("Entire Lipid COM Distance from Ligand Position at T=0")
plt.ylabel("count")
plt.xlabel("A")
plt.grid(False)
plt.savefig("Distance_from_t0.png", dpi=600)

# %%
radius = np.percentile(data.cylLigand, 95)
radius
# Out:
# 1.18869272096874

# %%
data.absZ.hist()
plt.title("Entire Ligand COM Cartesian Position (Z)")
plt.ylabel("count")
plt.xlabel("A")
plt.savefig("ZPosition.png", dpi=600)

# %%
data.relZ.hist()
plt.title("Entire Ligand COM Position (Z)\nRelative to Binding Site")
plt.ylabel("count")
plt.xlabel("A")
plt.savefig("relZPosition.png", dpi=600)

# %%
data.relY.hist()
plt.title("Entire Ligand COM Position (Y)")
plt.ylabel("count")
plt.xlabel("A")
plt.savefig("YPosition.png", dpi=600)

# %%
fig, ax = plt.subplots()
center = (data.relX[0], data.relY[0])
#center = (5.771076257226381, -0.38855978495432647)
area = plt.Circle(center, radius, color='orange')

#ax.add_patch(scatter)
ax.add_patch(area)
scatter = plt.scatter(data.relX, data.relY)
plt.scatter(center[0], center[1], color='r', label="t=0")
plt.title(f"Entire Lipid COM Position (XY)\nRadius={np.round(radius,4)}Å")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
plt.legend()

#plt.show()
plt.savefig("XYPosition.png", dpi=600)

# %%
def getDistance(center, point):
    return np.sqrt(np.sum(np.subtract(point, center)**2))

# %%
distXY = data.relX
for p in zip(data.relX, data.relY)
meanX = np.mean(data.relX)
meanY = np.mean(data.relY)
center = (meanX, meanY)
point = (0, 0)
getDistance(point, center)
# Out:
# 5.784142103476177

# %%
fig, ax = plt.subplots()
center = (data.relX[0], data.relY[0])
meanX = np.mean(data.relX)
meanY = np.mean(data.relY)
center = (meanX, meanY)
area = plt.Circle(center, radius, color='orange')

#ax.add_patch(scatter)
ax.add_patch(area)
scatter = plt.scatter(data.relX, data.relY)
plt.scatter(center[0], center[1], color='r', label="Geometric Center")
plt.title(f"Entire Lipid COM Position (XY)\nRadius={np.round(radius,4)}Å")
plt.ylabel("count")
plt.xlabel("A")
plt.axis('equal')
plt.legend()

#plt.show()
plt.savefig("XYPosition.png", dpi=600)

# %%
print(f"({meanX}, {meanY})")
# Out:
# (5.771076257226381, -0.38855978495432647)
