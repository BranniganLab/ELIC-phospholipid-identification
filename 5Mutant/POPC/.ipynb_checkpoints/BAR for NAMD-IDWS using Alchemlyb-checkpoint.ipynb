# %%
# USER PARAMETERS
from glob import glob

# fepoutFiles = glob('/home/tom/ELIC/ELIC_POEA/namd/popetopopa???.fepout')
# fepoutFiles = glob('/home/tom/ELIC/ELIC_CA_Aso_DLPC/namd/pctopgF???.fepout')
# fepoutFiles = glob('/home/tom/ELIC/ELIC_CA_Aso_DLPC/namd/petopc???.fepout')
# poutFiles = glob('/home/tom/RYR1/ClosedC3-TM_Only-APM_r9_L4827/namd/dis5A???.fepout')
# fepoutFiles = glob('/home/tom/RYR1/ClosedC3-TM_Only-PFL_L4827/namd/dis5C???.fepout')
# fepoutFiles = glob('/home/tom/RYR1/TM_Only-PFL_Omid202102/namd/disl4827a[!B]*fepout')
# fepoutFiles = glob('/home/tom/RYR1/TM_Only-PFL_Omid202102/namd/disopenl4827a[!B]*fepout')

# fepoutFiles = glob('/home/tom/ELIC/ELIC_Open/namd/pctopg6Ed*.fepout')
# fepoutFiles = glob('/home/tom/ELIC/ELIC_211_POPC/namd/petopg[!BCDEF]*.fepout')
# fepoutFiles = glob('/home/tom/ELIC/ELIC_211_POPC/namd/petopgB*.fepout')
# fepoutFiles.remove('/home/tom/ELIC/ELIC_211_POPC/namd/petopgC000.fepout')
# fepoutFiles.remove('/home/tom/ELIC/ELIC_211_POPC/namd/petopgC000a.fepout')
# fepoutFiles.remove('/home/tom/ELIC/ELIC_211_POPC/namd/petopgC000b.fepout')

fepoutFiles = glob('/home/tom/ELIC/POPC10/namd/petopcD*.fepout')
# fepoutFiles = glob('/home/tom/ELIC/Membrane_211/namd/pctopgA*.fepout')

temperature = 303.15

print(f"Will process {len(fepoutFiles)} fepout files.")
print('\n'.join(sorted(fepoutFiles)))
# Out:
# Will process 51 fepout files.
# /home/tom/ELIC/POPC10/namd/petopcD000.fepout
# /home/tom/ELIC/POPC10/namd/petopcD001.fepout
# /home/tom/ELIC/POPC10/namd/petopcD001a.fepout
# /home/tom/ELIC/POPC10/namd/petopcD002.fepout
# /home/tom/ELIC/POPC10/namd/petopcD003.fepout
# /home/tom/ELIC/POPC10/namd/petopcD004.fepout
# /home/tom/ELIC/POPC10/namd/petopcD005.fepout
# /home/tom/ELIC/POPC10/namd/petopcD006.fepout
# /home/tom/ELIC/POPC10/namd/petopcD007.fepout
# /home/tom/ELIC/POPC10/namd/petopcD008.fepout
# /home/tom/ELIC/POPC10/namd/petopcD009.fepout
# /home/tom/ELIC/POPC10/namd/petopcD010.fepout
# /home/tom/ELIC/POPC10/namd/petopcD011.fepout
# /home/tom/ELIC/POPC10/namd/petopcD012.fepout
# /home/tom/ELIC/POPC10/namd/petopcD013.fepout
# /home/tom/ELIC/POPC10/namd/petopcD014.fepout
# /home/tom/ELIC/POPC10/namd/petopcD015.fepout
# /home/tom/ELIC/POPC10/namd/petopcD016.fepout
# /home/tom/ELIC/POPC10/namd/petopcD017.fepout
# /home/tom/ELIC/POPC10/namd/petopcD018.fepout
# /home/tom/ELIC/POPC10/namd/petopcD019.fepout
# /home/tom/ELIC/POPC10/namd/petopcD020.fepout
# /home/tom/ELIC/POPC10/namd/petopcD021.fepout
# /home/tom/ELIC/POPC10/namd/petopcD022.fepout
# /home/tom/ELIC/POPC10/namd/petopcD023.fepout
# /home/tom/ELIC/POPC10/namd/petopcD024.fepout
# /home/tom/ELIC/POPC10/namd/petopcD025.fepout
# /home/tom/ELIC/POPC10/namd/petopcD026.fepout
# /home/tom/ELIC/POPC10/namd/petopcD027.fepout
# /home/tom/ELIC/POPC10/namd/petopcD028.fepout
# /home/tom/ELIC/POPC10/namd/petopcD029.fepout
# /home/tom/ELIC/POPC10/namd/petopcD030.fepout
# /home/tom/ELIC/POPC10/namd/petopcD031.fepout
# /home/tom/ELIC/POPC10/namd/petopcD032.fepout
# /home/tom/ELIC/POPC10/namd/petopcD033.fepout
# /home/tom/ELIC/POPC10/namd/petopcD034.fepout
# /home/tom/ELIC/POPC10/namd/petopcD035.fepout
# /home/tom/ELIC/POPC10/namd/petopcD036.fepout
# /home/tom/ELIC/POPC10/namd/petopcD037.fepout
# /home/tom/ELIC/POPC10/namd/petopcD038.fepout
# /home/tom/ELIC/POPC10/namd/petopcD039.fepout
# /home/tom/ELIC/POPC10/namd/petopcD040.fepout
# /home/tom/ELIC/POPC10/namd/petopcD041.fepout
# /home/tom/ELIC/POPC10/namd/petopcD042.fepout
# /home/tom/ELIC/POPC10/namd/petopcD043.fepout
# /home/tom/ELIC/POPC10/namd/petopcD044.fepout
# /home/tom/ELIC/POPC10/namd/petopcD045.fepout
# /home/tom/ELIC/POPC10/namd/petopcD046.fepout
# /home/tom/ELIC/POPC10/namd/petopcD047.fepout
# /home/tom/ELIC/POPC10/namd/petopcD048.fepout
# /home/tom/ELIC/POPC10/namd/petopcD049.fepout

# %%
from alchemlyb.parsing import namd
from alchemlyb.estimators import BAR
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from alchemlyb.visualisation.dF_state import plot_dF_state
plt.rcParams['figure.dpi'] = 150

# %%
u_nk = namd.extract_u_nk(fepoutFiles, temperature)
print(u_nk.info())
# Out:
# Warning: /home/tom/ELIC/POPC10/namd/petopcD005.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.102041, lambda2 = 0.122449; inferring lambda_idws to be 0.081633
# Warning: /home/tom/ELIC/POPC10/namd/petopcD010.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.204082, lambda2 = 0.22449; inferring lambda_idws to be 0.183673
# Warning: /home/tom/ELIC/POPC10/namd/petopcD015.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.306122, lambda2 = 0.326531; inferring lambda_idws to be 0.285714
# Warning: /home/tom/ELIC/POPC10/namd/petopcD020.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.408163, lambda2 = 0.428571; inferring lambda_idws to be 0.387755
# Warning: /home/tom/ELIC/POPC10/namd/petopcD025.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.510204, lambda2 = 0.530612; inferring lambda_idws to be 0.489796
# Warning: /home/tom/ELIC/POPC10/namd/petopcD030.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.612245, lambda2 = 0.632653; inferring lambda_idws to be 0.591837
# Warning: /home/tom/ELIC/POPC10/namd/petopcD035.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.714286, lambda2 = 0.734694; inferring lambda_idws to be 0.693878
# Warning: /home/tom/ELIC/POPC10/namd/petopcD040.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.816327, lambda2 = 0.836735; inferring lambda_idws to be 0.795918
# Warning: /home/tom/ELIC/POPC10/namd/petopcD045.fepout has IDWS data but lambda_idws not included.
#          lambda1 = 0.918367, lambda2 = 0.938776; inferring lambda_idws to be 0.897959
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 280534 entries, (200500.0, 0.0) to (1200000.0, 1.0)
# Data columns (total 50 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   0.0       15533 non-null  float64
#  1   0.020408  21033 non-null  float64
#  2   0.040816  16532 non-null  float64
#  3   0.061224  16500 non-null  float64
#  4   0.081633  16000 non-null  float64
#  5   0.102041  16000 non-null  float64
#  6   0.122449  16000 non-null  float64
#  7   0.142857  16500 non-null  float64
#  8   0.163265  16500 non-null  float64
#  9   0.183673  16000 non-null  float64
#  10  0.204082  16000 non-null  float64
#  11  0.22449   16000 non-null  float64
#  12  0.244898  16500 non-null  float64
#  13  0.265306  16500 non-null  float64
#  14  0.285714  16000 non-null  float64
#  15  0.306122  16000 non-null  float64
#  16  0.326531  16000 non-null  float64
#  17  0.346939  16500 non-null  float64
#  18  0.367347  16500 non-null  float64
#  19  0.387755  16000 non-null  float64
#  20  0.408163  16000 non-null  float64
#  21  0.428571  16000 non-null  float64
#  22  0.44898   16500 non-null  float64
#  23  0.469388  16500 non-null  float64
#  24  0.489796  16000 non-null  float64
#  25  0.510204  16000 non-null  float64
#  26  0.530612  16000 non-null  float64
#  27  0.55102   16500 non-null  float64
#  28  0.571429  16500 non-null  float64
#  29  0.591837  16000 non-null  float64
#  30  0.612245  16000 non-null  float64
#  31  0.632653  16000 non-null  float64
#  32  0.653061  16500 non-null  float64
#  33  0.673469  16500 non-null  float64
#  34  0.693878  16000 non-null  float64
#  35  0.714286  16000 non-null  float64
#  36  0.734694  16000 non-null  float64
#  37  0.755102  16500 non-null  float64
#  38  0.77551   16500 non-null  float64
#  39  0.795918  16000 non-null  float64
#  40  0.816327  16000 non-null  float64
#  41  0.836735  16000 non-null  float64
#  42  0.857143  16500 non-null  float64
#  43  0.877551  16500 non-null  float64
#  44  0.897959  16000 non-null  float64
#  45  0.918367  16000 non-null  float64
#  46  0.938776  16000 non-null  float64
#  47  0.959184  16500 non-null  float64
#  48  0.979592  22001 non-null  float64
#  49  1.0       16501 non-null  float64
# dtypes: float64(50)
# memory usage: 108.2 MB
# None

# %%
print(u_nk[0.0])
bar = BAR()
bar.fit(u_nk)
# Out:
# time       fep-lambda
# 200500.0   0.0           0.0
# 200600.0   0.0           0.0
# 200700.0   0.0           0.0
# 200800.0   0.0           0.0
# 200900.0   0.0           0.0
#                         ...
# 1199600.0  1.0           NaN
# 1199700.0  1.0           NaN
# 1199800.0  1.0           NaN
# 1199900.0  1.0           NaN
# 1200000.0  1.0           NaN
# Name: 0.0, Length: 280534, dtype: float64
# BAR()

# %%
# Extract data for plotting
states = bar.states_

f = bar.delta_f_.iloc[0, :] # dataframe
l = np.array([float(s) for s in states])
# lambda midpoints for each window
l_mid = 0.5*(l[1:] + l[:-1])

# FE differences are off diagonal
df = np.array([bar.delta_f_.iloc[i, i+1] for i in range(len(states)-1)])
# print(df * 0.593)
dg_kcal = df.cumsum() * 0.593
print(f"delta_G = {dg_kcal[-1]:.2f} kcal/mol")

# error estimates are too small because we use correlated data

tau = 5e3 # expected correlation length of series

# error estimates are off diagonal
ddf = np.array([bar.d_delta_f_.iloc[i, i+1] for i in range(len(states)-1)]) * np.sqrt(tau)

# Accumulate errors as sum of squares
errors = np.array([np.sqrt((ddf[:i]**2).sum()) for i in range(len(states))])
# print("Errors", errors)
# Out:
# delta_G = 0.30 kcal/mol

# %%
# print(bar.delta_f_)

print(f)

plt.errorbar(l, f, yerr=errors, marker='.', markersize=5)
# plt.xlabel('lambda')
# plt.ylabel('DeltaG(lambda) (kT)')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.tick_params(axis='both', which='major', labelsize=13)
plt.show()

plt.errorbar(l_mid, df, yerr=ddf, marker='.')
plt.xlabel('lambda')
plt.ylabel('Delta G per window (kT)')
plt.show()
# Out:
# 0.000000     0.000000
# 0.020408     8.670777
# 0.040816    14.955105
# 0.061224    19.275936
# 0.081633    22.332822
# 0.102041    25.183194
# 0.122449    27.713310
# 0.142857    29.634432
# 0.163265    31.180794
# 0.183673    32.189090
# 0.204082    32.843224
# 0.224490    33.301196
# 0.244898    33.369989
# 0.265306    33.101249
# 0.285714    32.534969
# 0.306122    31.629554
# 0.326531    30.352821
# 0.346939    28.923431
# 0.367347    27.339873
# 0.387755    25.432490
# 0.408163    23.546191
# 0.428571    21.689129
# 0.448980    19.695758
# 0.469388    17.666236
# 0.489796    15.651457
# 0.510204    15.829766
# 0.530612    18.209381
# 0.551020    20.435928
# 0.571429    22.548044
# 0.591837    24.702932
# 0.612245    26.668574
# 0.632653    28.487962
# 0.653061    30.554301
# 0.673469    32.552923
# 0.693878    34.300488
# 0.714286    35.439239
# 0.734694    36.065868
# 0.755102    36.540808
# 0.775510    36.635856
# 0.795918    36.362233
# 0.816327    35.245082
# 0.836735    33.419072
# 0.857143    31.322266
# 0.877551    28.831377
# 0.897959    25.755573
# 0.918367    21.912916
# 0.938776    17.420205
# 0.959184    12.407242
# 0.979592     6.762381
# 1.000000     0.512155
# Name: 0.0, dtype: float64

# %%
grouped = u_nk.groupby('fep-lambda')
data_list = [grouped.get_group(s) for s in states]

forward = []
forward_error = []
backward = []
backward_error = []
num_points = 10
for i in range(1, num_points+1):
    # forward
    partial = pd.concat([data[:int(len(data)/num_points*i)] for data in data_list])
    estimate = BAR().fit(partial)
    forward.append(estimate.delta_f_.iloc[0,-1])
    # For BAR, the error estimates are off-diagonal
    ddf = [estimate.d_delta_f_.iloc[i+1,i] * np.sqrt(tau) for i in range(len(states)-1)]
    error = np.sqrt((np.array(ddf)**2).sum())
    forward_error.append(error)

    # backward
    partial = pd.concat([data[-int(len(data)/num_points*i):] for data in data_list])
    estimate = BAR().fit(partial)
    backward.append(estimate.delta_f_.iloc[0,-1])
    ddf = [estimate.d_delta_f_.iloc[i+1,i] * np.sqrt(tau) for i in range(len(states)-1)]
    error = np.sqrt((np.array(ddf)**2).sum())
    backward_error.append(error)

from alchemlyb.visualisation import plot_convergence
ax = plot_convergence(forward, forward_error, backward, backward_error)
# ax.set_ylim(-40, -36)

# %%
u_nk = u_nk.sort_index(level=u_nk.index.names[1:])
states = u_nk.columns.values.tolist()
l = np.array([float(s) for s in states])
# lambda midpoints for each window
l_mid = 0.5*(l[1:] + l[:-1])

# group u_nk by lambda states
groups = u_nk.groupby(level=u_nk.index.names[1:])
N_k = [(len(groups.get_group(i)) if i in groups.groups else 0) for i in u_nk.columns]
dG_f = []
dG_b = []

for k in range(len(N_k) - 1):
    # get us from lambda step k
    uk = groups.get_group(states[k])
    # get w_F
    w_f = uk.iloc[:, k+1] - uk.iloc[:, k]
    dG_f.append(np.log(np.mean(np.exp(-1*w_f))))
    #plt.plot(np.array(w_f))

    # get us from lambda step k+1
    uk1 = groups.get_group(states[k+1])
    # get w_R
    w_b = uk1.iloc[:, k] - uk1.iloc[:, k+1]
    dG_b.append(np.log(np.mean(np.exp(-1*w_b))))

# plt.plot(l_mid, dG_f, '+', label="exp, fwd", markersize=10)
# plt.plot(l_mid, -1. * np.array(dG_b), '+', label="exp, bwd", markersize=10)
# plt.plot(l_mid, df, label="BAR")
plt.vlines(l_mid, np.zeros(len(l_mid)), dG_f + np.array(dG_b), label="fwd - bwd", linewidth=3)
plt.legend()
plt.title('Fwd-bwd discrepencies by lambda')
plt.xlabel('Lambda')
plt.ylabel('Diff. in delta-G')
# Out:
# Text(0, 0.5, 'Diff. in delta-G')

# %%
plt.hist(dG_f + np.array(dG_b), bins=50);
plt.title('Distribution of fwd-bwd discrepancies')
plt.xlabel('Difference in delta-G')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
x = np.concatenate((
    # np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpopg10Aw1.colvars.traj'),
    # np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpope10Cc1.colvars.traj'),
    np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpopc10Dc1.colvars.traj'),
#     np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpopc10Dc2.colvars.traj'),
#     np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpope10Dc1.colvars.traj'),
#     np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpope10Dc2.colvars.traj'),
#     np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpopg10Dc1.colvars.traj'),
#     np.loadtxt('/home/tom/ELIC/ELIC_Open/namd/prodpopg10Dc2.colvars.traj'),
#    np.loadtxt('/home/tom/ELIC/ELIC_in_211/namd/prodpopg10A1.colvars.traj'),
    # np.loadtxt('/home/tom/ELIC/ELIC_5mut_in_211/namd/prodpopg10A1.colvars.traj'),
    # np.loadtxt('/home/tom/ELIC/ELIC_5mut_in_211/namd/prodpopg10A2.colvars.traj'),

))

the_title = 'ELIC_5m+POPC in POPC, DBC wall, Chipot NBFIX'
plt.hist(x[:, 1], bins=50)
plt.xlabel('DBC restraint coordinate')
plt.ylabel('Count')
plt.title(the_title)

plt.figure()
plt.plot(x[:, 1], linewidth=0.5)
plt.xlabel('Timestep / 100')
plt.ylabel('DBC restraint coordinate')
plt.title(the_title)
